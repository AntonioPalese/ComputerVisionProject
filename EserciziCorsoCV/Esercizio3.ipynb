# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
'''Your code will take an input tensor input with shape (n, iC, H, W) and a kernel kernel with shape (oC, iC, kH, kW). 
It needs then to apply a 2D convolution over input, using kernel as kernel tensor and no bias, using a stride of 1, 
no dilation, no grouping, and no padding, and store the result in out. Both input and kernel have dtype torch.float32.'''


import random
import torch

n = random.randint(2, 6)
iC = random.randint(2, 6)
oC = 3
H = random.randint(10, 20)
W = random.randint(10, 20)


#input = torch.rand(n, iC, H, W, dtype=torch.float32)
+
input2 = plt.imread('immagineragazze_chiara.jpg')

input2 = input2[:410, :594, :]

input1.reshape((1, input1.shape[0], input1.shape[1]))

input = np.concatenate((input1, input2), axis=2)
#kernel = torch.rand(oC, iC, kH, kW, dtype=torch.float32)
kernel = torch.tensor([[[[0, -1, 0],
                    [-1, 4, -1],
                    [0, -1, 0]],
                    [[0, -1, 0],
                    [-1, 4, -1],
                    [0, -1, 0]],
                    [[0, -1, 0],
                    [-1, 4, -1],
                    [0, -1, 0]]],
                      [[[0, -1, 0],
                    [-1, 4, -1],
                    [0, -1, 0]],
                    [[0, -1, 0],
                    [-1, 4, -1],
                    [0, -1, 0]],
                    [[0, -1, 0],
                    [-1, 4, -1],
                    [0, -1, 0]]],
                      [[[0, -1, 0],
                    [-1, 4, -1],
                    [0, -1, 0]],
                    [[0, -1, 0],
                    [-1, 4, -1],
                    [0, -1, 0]],
                    [[0, -1, 0],
                    [-1, 4, -1],
                    [0, -1, 0]]]],                      
                      dtype=torch.float32)

kH = kernel.shape[1]
kW = kernel.shape[2]
iC = kernel.shape[0]
kH, kW, iC
kernel.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-fe54316fb5dc> in <module>
#      20 input2 = input2[:410, :594, :]
#      21
# ---> 22 input1.reshape((1, input1.shape[0], input1.shape[1]))
#      23
#      24 input = np.concatenate((input1, input2), axis=2)
#
# ValueError: cannot reshape array of size 730620 into shape (1,410,594)

# %%
input.shape[2]
input1 = plt.imread('eclissi.jpg')
plt.imshow(input1)
input1.shape
# Out:
# (410, 594, 3)

# %%
n, iC, H, W = input.shape
tuple(input.shape)
input.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-f56250d41adb> in <module>
# ----> 1 n, iC, H, W = input.shape
#       2 tuple(input.shape)
#       3 input.shape
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
kernel.shape
# Out:
# torch.Size([3, 3, 3])

# %%
out = torch.zeros((n, oC, (H - kH + 1), (W - kW + 1)))  
for r in range(0, H - kH + 1):
    for c in range(0, W - kW + 1):
        window = input[:,:,r:r+kH,c:c+kW]
        window = window.reshape((n, 1, iC, kH, kW))
        k = kernel.reshape((1, oC, iC, kH, kW))
        res = (window * k).sum((2, 3, 4))
        out[:,:, r, c] = res
        print(res.shape, (r, c))
# Out:
# torch.Size([4, 1]) (0, 0)
# torch.Size([4, 1]) (0, 1)
# torch.Size([4, 1]) (0, 2)
# torch.Size([4, 1]) (0, 3)
# torch.Size([4, 1]) (0, 4)
# torch.Size([4, 1]) (0, 5)
# torch.Size([4, 1]) (0, 6)
# torch.Size([4, 1]) (0, 7)
# torch.Size([4, 1]) (1, 0)
# torch.Size([4, 1]) (1, 1)
# torch.Size([4, 1]) (1, 2)
# torch.Size([4, 1]) (1, 3)
# torch.Size([4, 1]) (1, 4)
# torch.Size([4, 1]) (1, 5)
# torch.Size([4, 1]) (1, 6)
# torch.Size([4, 1]) (1, 7)
# torch.Size([4, 1]) (2, 0)
# torch.Size([4, 1]) (2, 1)
# torch.Size([4, 1]) (2, 2)
# torch.Size([4, 1]) (2, 3)
# torch.Size([4, 1]) (2, 4)
# torch.Size([4, 1]) (2, 5)
# torch.Size([4, 1]) (2, 6)
# torch.Size([4, 1]) (2, 7)
# torch.Size([4, 1]) (3, 0)
# torch.Size([4, 1]) (3, 1)
# torch.Size([4, 1]) (3, 2)
# torch.Size([4, 1]) (3, 3)
# torch.Size([4, 1]) (3, 4)
# torch.Size([4, 1]) (3, 5)
# torch.Size([4, 1]) (3, 6)
# torch.Size([4, 1]) (3, 7)
# torch.Size([4, 1]) (4, 0)
# torch.Size([4, 1]) (4, 1)
# torch.Size([4, 1]) (4, 2)
# ...

# %%
out = torch.zeros((n, oC, (H - kH + 1), (W - kW + 1)))
for r in range(0, H - kH + 1):
    for c in range(0, W - kW + 1):
        out[:,:, r, c] = (input[:,:,r:r+kH,c:c+kW].reshape((n, 1, iC, kH, kW)) * kernel.reshape((1, oC, iC, kH, kW))).sum((2, 3, 4))
        #print(res.shape, (r, c))

# %%
out.shape
# Out:
# torch.Size([4, 1, 18, 8])
