# %%
# loop over the input images
#path = 'BlurredImages/blurred04.jpg'

import argparse
import cv2
import matplotlib.pyplot as plt

def variance_of_laplacian(image):
    # compute the Laplacian of the image and then return the focus
    # measure, which is simply the variance of the Laplacian
    return cv2.Laplacian(image, cv2.CV_64F)




for i in range(1,10):
    path = 'BlurredImages/blurred0' + str(i) +'.jpg'
    print(path)
    image = cv2.imread(path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    imr = variance_of_laplacian(gray)
    fm = imr.var()
    print(imr.shape)
    text = "Not Blurry"
    
    if fm < 134:
        text = "Blurry"
    # show the image
    cv2.putText(image, "{}: {:.2f}".format(text, fm), (10, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 3)
    plt.imshow(imr, cmap='gray')
    plt.show()
    cv2.imshow("Image", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# BlurredImages/blurred01.jpg
# (183, 275)
# BlurredImages/blurred02.jpg
# (877, 1300)
# BlurredImages/blurred03.jpg
# (500, 750)
# BlurredImages/blurred04.jpg
# (1409, 2127)
# BlurredImages/blurred05.jpg
# (940, 1920)
# BlurredImages/blurred06.jpg
# (1120, 1120)
# BlurredImages/blurred07.jpg
# (400, 800)
# BlurredImages/blurred08.jpg
# (177, 284)
# BlurredImages/blurred09.jpg
# (549, 976)
